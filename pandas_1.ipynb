# %%
import pandas as pd


data = [1,2,3,4]
series = pd.Series(data)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
series = pd.Series ([1,2,3,4],index= ['a','b','c','d'])
print (series)
type(series)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64
# pandas.core.series.Series

# %%
data = {'Name': ['Alice','Bob','Charlie'], 'Age': [24,25,29]}
df = pd.DataFrame(data)
print (df)
# Out:
#       Name  Age
# 0    Alice   24
# 1      Bob   25
# 2  Charlie   29

# %%
df.shape
# Out:
# (3, 2)

# %%
df.head()
# Out:
#       Name  Age
# 0    Alice   24
# 1      Bob   25
# 2  Charlie   29

# %%
df.tail()
# Out:
#       Name  Age
# 0    Alice   24
# 1      Bob   25
# 2  Charlie   29

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   26.000000
# std     2.645751
# min    24.000000
# 25%    24.500000
# 50%    25.000000
# 75%    27.000000
# max    29.000000

# %%
df.dtypes
# Out:
# Name    object
# Age      int64
# dtype: object

# %%
file_df = pd.read_csv('./test.csv')
file_df2 = pd.read_excel('./users.xlsx')

# %%
file_df.head()
# Out:
#    id           name                      email  age       city  country  \
# 0   1  Alice Johnson  alice.johnson@example.com   24   New York      USA
# 1   2      Bob Smith      bob.smith@example.com   31     London       UK
# 2   3    Charlie Lee    charlie.lee@example.com   27    Toronto   Canada
# 3   4    Diana Patel    diana.patel@example.com   35  Ahmedabad    India
# 4   5    Eric Müller   eric.mueller@example.com   29     Berlin  Germany
#
#   signup_date  is_active
# 0  2024-01-12       True
# 1  2023-11-03       True
# 2  2024-02-18      False
# 3  2022-09-25       True
# 4  2023-06-14       True

# %%
file_df2.head()
# Out:
#    id           name                      email  age      city country  \
# 0   1  Alice Johnson  alice.johnson@example.com   24  New York     USA
# 1   2      Bob Smith      bob.smith@example.com   31    London      UK
#
#   signup_date  is_active
# 0  2024-01-12       True
# 1  2023-11-03       True

# %%
#Creating a simple Dataframe 

data = { 'Name': ['Alice','Bob', 'Charlie'], 'Age': [24,27,22], 'City': ['New York', 'Los Angles', 'Chicago']}
df = pd.DataFrame(data, index = ['a','b', 'c'])
print (df)


#loc df.loc [row label, column ]
# Out:
#       Name  Age        City
# a    Alice   24    New York
# b      Bob   27  Los Angles
# c  Charlie   22     Chicago
